# %% [markdown]
# ## Harjoitustyö

# %% [markdown]
# ## Vaihe 1

# %% [markdown]
# #### Tehtävä 1. Hae Digitrafficin REST-rajapintapalvelusta (JSON-formaatissa) aktiiviset junat pääteosoitteella `/live-trains` Helsingin asemalta, joiden hakuparametrit ovat seuraavat:
# * arrived_trains=10
# * departed_trains=10
# * include_nonstopping=False

# %%
import requests
import pandas as pd

# %%
url = "https://rata.digitraffic.fi/api/v1"
endpoint = "/live-trains"
station = "/station/HKI"
search_train = "?arrived_trains=10&departed_trains=10&include_nonstopping=False"

url2 = f"{url}{endpoint}{station}{search_train}"

req = requests.get(url2)
# req.status_code

train_info = req.json()
#train_info

# %% [markdown]
# #### Tehtävä 2. Tämän jälkeen lue kyseinen data Pandasin dataframeen ilman muokkaamista, jolloin sarakkeiden otsikot ovat seuraavanlaiset:
#
#  `cancelled`,
#  `commuterLineID`,
#  `departureDate`,
#  `operatorShortCode`,
#  `operatorUICCode`,
#  `runningCurrently`,
#  `timeTableRows`,
#  `timetableAcceptanceDate`,
#  `timetableType`,
#  `trainCategory`,
#  `trainNumber`,
#  `trainType`,
#  `version`

# %%
#
train_df = pd.DataFrame(train_info)
train_df
# Out:
#     trainNumber departureDate  operatorUICCode operatorShortCode trainType  \
# 0            67    2023-03-14               10                vr         S
# 1            87    2023-03-14               10                vr        IC
# 2          8106    2023-03-14               10                vr        HL
# 3          8114    2023-03-14               10                vr        HL
# 4          8117    2023-03-14               10                vr        HL
# 5          8121    2023-03-14               10                vr        HL
# 6          8350    2023-03-14               10                vr        HL
# 7          8466    2023-03-14               10                vr        HL
# 8          8471    2023-03-14               10                vr        HL
# 9          8666    2023-03-14               10                vr        HL
# 10         8667    2023-03-14               10                vr        HL
# 11         8673    2023-03-14               10                vr        HL
# 12         8674    2023-03-14               10                vr        HL
# 13         8675    2023-03-14               10                vr        HL
# 14         8861    2023-03-14               10                vr        HL
# 15         8862    2023-03-14               10                vr        HL
# 16         8869    2023-03-14               10                vr        HL
# 17         8870    2023-03-14               10                vr        HL
# 18         9134    2023-03-14               10                vr        HL
# 19         9138    2023-03-14               10                vr        HL
# 20         9157    2023-03-14               10                vr        HL
# 21         9159    2023-03-14               10                vr        HL
# 22         9163    2023-03-14               10                vr        HL
# 23         9670    2023-03-14               10                vr        HL
# 24         9679    2023-03-14               10                vr        HL
# 25         9681    2023-03-14               10                vr        HL
# 26        64020    2023-03-14               10                vr         W
# 27        64022    2023-03-14               10                vr         W
# 28        64122    2023-03-14               10                vr         W
# 29        64420    2023-03-14               10                vr         W
#
#     trainCategory commuterLineID  runningCurrently  cancelled       version  \
# 0   Long-distance                            False      False  285115745778
# 1   Long-distance                             True      False  285115927941
# 2        Commuter              A             False       True  285114374671
# 3        Commuter              A              True      False  285115918884
# 4        Commuter              A             False      False  285115935797
# 5        Commuter              A             False      False  285115931662
# 6        Commuter              E             False      False  285115831126
# 7        Commuter              U              True      False  285115919847
# 8        Commuter              U              True      False  285115935078
# 9        Commuter              P             False      False  285115880577
# 10       Commuter              P              True      False  285115922522
# 11       Commuter              P              True      False  285115918884
# 12       Commuter              P              True      False  285115931662
# 13       Commuter              P             False      False  285115872068
# 14       Commuter              I             False      False  285115858424
# 15       Commuter              I             False      False  285115919847
# 16       Commuter              I              True      False  285115933937
# 17       Commuter              I              True      False  285115917050
# 18       Commuter              K             False      False  285115842167
# 19       Commuter              K             False      False  285115924052
# 20       Commuter              K              True      False  285115925755
# 21       Commuter              K              True      False  285115931663
# 22       Commuter              K             False      False  285115901733
# 23       Commuter              R             False      False  285115927941
# 24       Commuter              R             False       True  285114797428
# 25       Commuter              R              True      False  285115935078
# 26       Shunting                            False      False  285115879913
# 27       Shunting                             True      False  285115901091
# 28       Shunting                            False      False  285115891032
# 29       Shunting                            False      False  285115851011
#
#    timetableType   timetableAcceptanceDate  \
# 0        REGULAR  2022-12-15T06:04:43.000Z
# 1        REGULAR  2022-08-15T06:10:16.000Z
# 2        REGULAR  2022-12-15T06:04:43.000Z
# 3        REGULAR  2022-12-15T06:04:43.000Z
# 4        REGULAR  2022-12-15T06:04:43.000Z
# 5        REGULAR  2022-12-15T06:04:43.000Z
# 6        REGULAR  2022-12-15T06:04:43.000Z
# 7        REGULAR  2022-12-15T06:04:43.000Z
# 8        REGULAR  2022-12-15T06:04:43.000Z
# 9        REGULAR  2022-12-15T06:04:43.000Z
# 10       REGULAR  2022-12-15T06:04:43.000Z
# 11       REGULAR  2022-12-15T06:04:43.000Z
# 12       REGULAR  2022-12-15T06:04:43.000Z
# 13       REGULAR  2022-12-15T06:04:43.000Z
# 14       REGULAR  2022-12-15T06:04:43.000Z
# 15       REGULAR  2022-12-15T06:04:43.000Z
# 16       REGULAR  2022-12-15T06:04:43.000Z
# 17       REGULAR  2022-12-15T06:04:43.000Z
# 18       REGULAR  2022-12-15T06:04:43.000Z
# 19       REGULAR  2022-12-15T06:04:43.000Z
# 20       REGULAR  2022-12-15T06:04:43.000Z
# 21       REGULAR  2022-12-15T06:04:43.000Z
# 22       REGULAR  2022-12-15T06:04:43.000Z
# 23       REGULAR  2022-11-03T06:29:25.000Z
# 24       REGULAR  2022-11-03T06:29:25.000Z
# 25       REGULAR  2022-11-03T06:29:25.000Z
# 26       REGULAR  2022-11-03T06:29:25.000Z
# 27       REGULAR  2022-11-03T06:29:25.000Z
# 28       REGULAR  2022-11-03T06:29:25.000Z
# 29       REGULAR  2022-11-03T06:29:25.000Z
#
#                                         timeTableRows
# 0   [{'stationShortCode': 'HKI', 'stationUICCode':...
# 1   [{'stationShortCode': 'HKI', 'stationUICCode':...
# 2   [{'stationShortCode': 'LPV', 'stationUICCode':...
# 3   [{'stationShortCode': 'LPV', 'stationUICCode':...
# 4   [{'stationShortCode': 'HKI', 'stationUICCode':...
# 5   [{'stationShortCode': 'HKI', 'stationUICCode':...
# 6   [{'stationShortCode': 'KLH', 'stationUICCode':...
# 7   [{'stationShortCode': 'KKN', 'stationUICCode':...
# 8   [{'stationShortCode': 'HKI', 'stationUICCode':...
# 9   [{'stationShortCode': 'HKI', 'stationUICCode':...
# 10  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 11  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 12  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 13  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 14  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 15  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 16  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 17  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 18  [{'stationShortCode': 'KE', 'stationUICCode': ...
# 19  [{'stationShortCode': 'KE', 'stationUICCode': ...
# 20  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 21  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 22  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 23  [{'stationShortCode': 'RI', 'stationUICCode': ...
# 24  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 25  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 26  [{'stationShortCode': 'ILR', 'stationUICCode':...
# 27  [{'stationShortCode': 'ILR', 'stationUICCode':...
# 28  [{'stationShortCode': 'ILR', 'stationUICCode':...
# 29  [{'stationShortCode': 'ILR', 'stationUICCode':...

# %% [markdown]
# #### Tehtävä 3. Poista kaikki muut sarakkeet paitsi `timeTableRows` ja `trainNumber`

# %%
#
# train_pd = train_pd[(train_pd["timeTableRows"]) & (train_pd["trainNumber"])]
# train_pd
train_df = train_df.loc[:,["trainNumber","timeTableRows"]]
train_df
# Out:
#     trainNumber                                      timeTableRows
# 0            67  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 1            87  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 2          8106  [{'stationShortCode': 'LPV', 'stationUICCode':...
# 3          8114  [{'stationShortCode': 'LPV', 'stationUICCode':...
# 4          8117  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 5          8121  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 6          8350  [{'stationShortCode': 'KLH', 'stationUICCode':...
# 7          8466  [{'stationShortCode': 'KKN', 'stationUICCode':...
# 8          8471  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 9          8666  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 10         8667  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 11         8673  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 12         8674  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 13         8675  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 14         8861  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 15         8862  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 16         8869  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 17         8870  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 18         9134  [{'stationShortCode': 'KE', 'stationUICCode': ...
# 19         9138  [{'stationShortCode': 'KE', 'stationUICCode': ...
# 20         9157  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 21         9159  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 22         9163  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 23         9670  [{'stationShortCode': 'RI', 'stationUICCode': ...
# 24         9679  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 25         9681  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 26        64020  [{'stationShortCode': 'ILR', 'stationUICCode':...
# 27        64022  [{'stationShortCode': 'ILR', 'stationUICCode':...
# 28        64122  [{'stationShortCode': 'ILR', 'stationUICCode':...
# 29        64420  [{'stationShortCode': 'ILR', 'stationUICCode':...

# %% [markdown]
# #### Tehtävä 4. Tämän jälkeen pura `timeTableRows` sarakkeen arvot jokaisesta junasta erikseen (sarakkeen arvo jokaiselle junalle sisältää useampia JSON-objekteja) ja lisää dataan mukaan junan tiedot yksilöivä `trainNumber`

# %%
#

t_list = []

for i in train_df["timeTableRows"]:
    for j in i:
        t_list.append(j)
# t_list
train_l = pd.DataFrame(t_list)    
train_l
# Out:
#      stationShortCode  stationUICCode countryCode       type  trainStopping  \
# 0                 HKI               1          FI  DEPARTURE           True
# 1                 PSL              10          FI    ARRIVAL           True
# 2                 PSL              10          FI  DEPARTURE           True
# 3                 KÄP             977          FI    ARRIVAL          False
# 4                 KÄP             977          FI  DEPARTURE          False
# ...               ...             ...         ...        ...            ...
# 1247              HKI               1          FI    ARRIVAL           True
# 1248              ILR            1030          FI  DEPARTURE           True
# 1249              PSL              10          FI    ARRIVAL          False
# 1250              PSL              10          FI  DEPARTURE          False
# 1251              HKI               1          FI    ARRIVAL           True
#
#      commercialStop commercialTrack  cancelled             scheduledTime  \
# 0              True               8      False  2023-03-14T12:03:00.000Z
# 1              True               3      False  2023-03-14T12:08:00.000Z
# 2              True               3      False  2023-03-14T12:09:00.000Z
# 3               NaN                      False  2023-03-14T12:11:00.000Z
# 4               NaN                      False  2023-03-14T12:11:00.000Z
# ...             ...             ...        ...                       ...
# 1247           True               4      False  2023-03-14T12:15:00.000Z
# 1248           True             774      False  2023-03-14T11:54:00.000Z
# 1249            NaN               7      False  2023-03-14T12:04:00.000Z
# 1250            NaN               7      False  2023-03-14T12:04:00.000Z
# 1251           True               8      False  2023-03-14T12:09:00.000Z
#
#                     actualTime  differenceInMinutes causes  trainNumber  \
# 0     2023-03-14T12:03:57.000Z                  1.0     []           87
# 1     2023-03-14T12:08:29.000Z                  0.0     []           87
# 2                          NaN                  0.0     []           87
# 3                          NaN                  0.0     []           87
# 4                          NaN                  0.0     []           87
# ...                        ...                  ...    ...          ...
# 1247                       NaN                 -1.0     []        64122
# 1248  2023-03-14T11:54:38.000Z                  1.0     []        64420
# 1249  2023-03-14T11:59:27.000Z                 -5.0     []        64420
# 1250  2023-03-14T11:59:40.000Z                 -4.0     []        64420
# 1251  2023-03-14T12:07:30.000Z                 -1.0     []        64420
#
#                                              trainReady  \
# 0     {'source': 'KUPLA', 'accepted': True, 'timesta...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1247                                                NaN
# 1248                                                NaN
# 1249                                                NaN
# 1250                                                NaN
# 1251                                                NaN
#
#               liveEstimateTime estimateSource
# 0                          NaN            NaN
# 1                          NaN            NaN
# 2     2023-03-14T12:09:18.000Z      COMBOCALC
# 3     2023-03-14T12:11:20.000Z      COMBOCALC
# 4     2023-03-14T12:11:20.000Z      COMBOCALC
# ...                        ...            ...
# 1247  2023-03-14T12:13:08.000Z      COMBOCALC
# 1248                       NaN            NaN
# 1249                       NaN            NaN
# 1250                       NaN            NaN
# 1251                       NaN            NaN
#
# [1252 rows x 16 columns]

# %% [markdown]
# #### Tehtävä 5. Pudota sitten seuraavat sarakkeet datasta: `causes`, `estimateSource`, `liveEstimateTime`, `differenceInMinutes`, `commercialStop` ja `trainReady`

# %%
#
train_l.drop(["causes","estimateSource","liveEstimateTime","differenceInMinutes","commercialStop","trainReady"], inplace=True, axis=1)
train_l
# Out:
#      stationShortCode  stationUICCode countryCode       type  trainStopping  \
# 0                 HKI               1          FI  DEPARTURE           True
# 1                 PSL              10          FI    ARRIVAL           True
# 2                 PSL              10          FI  DEPARTURE           True
# 3                 KÄP             977          FI    ARRIVAL          False
# 4                 KÄP             977          FI  DEPARTURE          False
# ...               ...             ...         ...        ...            ...
# 1247              HKI               1          FI    ARRIVAL           True
# 1248              ILR            1030          FI  DEPARTURE           True
# 1249              PSL              10          FI    ARRIVAL          False
# 1250              PSL              10          FI  DEPARTURE          False
# 1251              HKI               1          FI    ARRIVAL           True
#
#      commercialTrack  cancelled             scheduledTime  \
# 0                  8      False  2023-03-14T12:03:00.000Z
# 1                  3      False  2023-03-14T12:08:00.000Z
# 2                  3      False  2023-03-14T12:09:00.000Z
# 3                         False  2023-03-14T12:11:00.000Z
# 4                         False  2023-03-14T12:11:00.000Z
# ...              ...        ...                       ...
# 1247               4      False  2023-03-14T12:15:00.000Z
# 1248             774      False  2023-03-14T11:54:00.000Z
# 1249               7      False  2023-03-14T12:04:00.000Z
# 1250               7      False  2023-03-14T12:04:00.000Z
# 1251               8      False  2023-03-14T12:09:00.000Z
#
#                     actualTime  trainNumber
# 0     2023-03-14T12:03:57.000Z           87
# 1     2023-03-14T12:08:29.000Z           87
# 2                          NaN           87
# 3                          NaN           87
# 4                          NaN           87
# ...                        ...          ...
# 1247                       NaN        64122
# 1248  2023-03-14T11:54:38.000Z        64420
# 1249  2023-03-14T11:59:27.000Z        64420
# 1250  2023-03-14T11:59:40.000Z        64420
# 1251  2023-03-14T12:07:30.000Z        64420
#
# [1252 rows x 10 columns]

# %% [markdown]
# #### Tehtävä 6. Täytä jokaisen rivin sarakkeen `actualTime` puuttuvat arvot `scheduledTime` -sarakkeen arvolla.

# %%
#
train_l['actualTime'].fillna(inplace=True,value=train_l['scheduledTime'])
train_l
# Out:
#      stationShortCode  stationUICCode countryCode       type  trainStopping  \
# 0                 HKI               1          FI  DEPARTURE           True
# 1                 PSL              10          FI    ARRIVAL           True
# 2                 PSL              10          FI  DEPARTURE           True
# 3                 KÄP             977          FI    ARRIVAL          False
# 4                 KÄP             977          FI  DEPARTURE          False
# ...               ...             ...         ...        ...            ...
# 1247              HKI               1          FI    ARRIVAL           True
# 1248              ILR            1030          FI  DEPARTURE           True
# 1249              PSL              10          FI    ARRIVAL          False
# 1250              PSL              10          FI  DEPARTURE          False
# 1251              HKI               1          FI    ARRIVAL           True
#
#      commercialTrack  cancelled             scheduledTime  \
# 0                  8      False  2023-03-14T12:03:00.000Z
# 1                  3      False  2023-03-14T12:08:00.000Z
# 2                  3      False  2023-03-14T12:09:00.000Z
# 3                         False  2023-03-14T12:11:00.000Z
# 4                         False  2023-03-14T12:11:00.000Z
# ...              ...        ...                       ...
# 1247               4      False  2023-03-14T12:15:00.000Z
# 1248             774      False  2023-03-14T11:54:00.000Z
# 1249               7      False  2023-03-14T12:04:00.000Z
# 1250               7      False  2023-03-14T12:04:00.000Z
# 1251               8      False  2023-03-14T12:09:00.000Z
#
#                     actualTime  trainNumber
# 0     2023-03-14T12:03:57.000Z           87
# 1     2023-03-14T12:08:29.000Z           87
# 2     2023-03-14T12:09:00.000Z           87
# 3     2023-03-14T12:11:00.000Z           87
# 4     2023-03-14T12:11:00.000Z           87
# ...                        ...          ...
# 1247  2023-03-14T12:15:00.000Z        64122
# 1248  2023-03-14T11:54:38.000Z        64420
# 1249  2023-03-14T11:59:27.000Z        64420
# 1250  2023-03-14T11:59:40.000Z        64420
# 1251  2023-03-14T12:07:30.000Z        64420
#
# [1252 rows x 10 columns]

# %% [markdown]
# ## Vaihe 2
#
# #### Tehtävä 7. Pura tämän kansion sisällä olevan `data.html` -tiedoston `table`-elementin solujen arvot käyttäen regex-syntaksia ja yhdistä ne vaiheessa 1 luotuun dataframeen. Huom: tehtävässä tulee käyttää vain regexiä (Esim. Pandasin read_html()-metodin käyttö on kielletty)!

# %%
import re
import urllib.request

# %%
url = 'file:///C:/Users/sanni/Aida/ttc8030-harjoitukset/harjoitustyo/data.html'
html = urllib.request.urlopen(url).read()
html = html.decode()

pattern = r'<th>(.*)</th>' #th:t
pattern2 = r'<td>\s+(.*?)\s+</td>' #kaikki td:t
ths = re.findall(pattern, html)
tds = re.findall(pattern2, html)
# ths
# tds

actualtime = tds[::10]
cancelled = tds[1::10]
commercialtrack =tds[2::10]
countrycode = tds[3::10]
scheduledtime = tds[4::10]
shortcode = tds[5::10]
uiccode = tds[6::10]
trainstopping = tds[7::10]
ttype = tds[8::10]
trainnumber = tds[9::10]

generated_dataframe = pd.DataFrame({ths[5]:shortcode,
                                    ths[6]:uiccode,
                                   ths[3]:countrycode,
                                    ths[8]:ttype,
                                   ths[7]:trainstopping,
                                   ths[2]:commercialtrack,
                                   ths[1]:cancelled,
                                   ths[4]:scheduledtime,
                                   ths[0]:actualtime,
                                   ths[9]:trainnumber})

# generated_dataframe

combined_df = pd.concat([train_l, generated_dataframe])
combined_df.reset_index(inplace=True,drop=True)
combined_df
# Out:
#      stationShortCode stationUICCode countryCode       type trainStopping  \
# 0                 HKI              1          FI  DEPARTURE          True
# 1                 PSL             10          FI    ARRIVAL          True
# 2                 PSL             10          FI  DEPARTURE          True
# 3                 KÄP            977          FI    ARRIVAL         False
# 4                 KÄP            977          FI  DEPARTURE         False
# ...               ...            ...         ...        ...           ...
# 1250              PSL             10          FI  DEPARTURE         False
# 1251              HKI              1          FI    ARRIVAL          True
# 1252              JVS           1272          FI  DEPARTURE         False
# 1253             R702          98998          FI    ARRIVAL         False
# 1254              ILA          98998          FI    ARRIVAL             9
#
#      commercialTrack cancelled             scheduledTime  \
# 0                  8     False  2023-03-14T12:03:00.000Z
# 1                  3     False  2023-03-14T12:08:00.000Z
# 2                  3     False  2023-03-14T12:09:00.000Z
# 3                        False  2023-03-14T12:11:00.000Z
# 4                        False  2023-03-14T12:11:00.000Z
# ...              ...       ...                       ...
# 1250               7     False  2023-03-14T12:04:00.000Z
# 1251               8     False  2023-03-14T12:09:00.000Z
# 1252                     False  2019-08-06T04:48:00.000Z
# 1253                     False  2019-08-06T06:04:39.000Z
# 1254                     False  2019-08-06T07:03:12.000Z
#
#                     actualTime trainNumber
# 0     2023-03-14T12:03:57.000Z          87
# 1     2023-03-14T12:08:29.000Z          87
# 2     2023-03-14T12:09:00.000Z          87
# 3     2023-03-14T12:11:00.000Z          87
# 4     2023-03-14T12:11:00.000Z          87
# ...                        ...         ...
# 1250  2023-03-14T11:59:40.000Z       64420
# 1251  2023-03-14T12:07:30.000Z       64420
# 1252  2019-08-06T04:48:00.000Z         150
# 1253  2019-08-06T06:04:39.000Z         150
# 1254  2019-08-06T07:03:12.000Z        8337
#
# [1255 rows x 10 columns]

# %% [markdown]
# ## Vaihe 3
#
# #### Tehtävä 8. Tee SQLite tietokanta ja lisää sinne vaiheen 2 tuloksena saatu dataframe.

# %%
#Vielä tämä
