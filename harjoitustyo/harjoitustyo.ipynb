# %% [markdown]
# ## Harjoitustyö

# %% [markdown]
# ## Vaihe 1

# %% [markdown]
# #### Tehtävä 1. Hae Digitrafficin REST-rajapintapalvelusta (JSON-formaatissa) aktiiviset junat pääteosoitteella `/live-trains` Helsingin asemalta, joiden hakuparametrit ovat seuraavat:
# * arrived_trains=10
# * departed_trains=10
# * include_nonstopping=False

# %%
import requests
import pandas as pd

# %%
url = "https://rata.digitraffic.fi/api/v1"
endpoint = "/live-trains"
station = "/station/HKI"
search_train = "?arrived_trains=10&departed_trains=10&include_nonstopping=False"

url2 = f"{url}{endpoint}{station}{search_train}"

req = requests.get(url2)
# req.status_code

train_info = req.json()
#train_info

# %% [markdown]
# #### Tehtävä 2. Tämän jälkeen lue kyseinen data Pandasin dataframeen ilman muokkaamista, jolloin sarakkeiden otsikot ovat seuraavanlaiset:
#
#  `cancelled`,
#  `commuterLineID`,
#  `departureDate`,
#  `operatorShortCode`,
#  `operatorUICCode`,
#  `runningCurrently`,
#  `timeTableRows`,
#  `timetableAcceptanceDate`,
#  `timetableType`,
#  `trainCategory`,
#  `trainNumber`,
#  `trainType`,
#  `version`

# %%
#
train_df = pd.DataFrame(train_info)
train_df
# Out:
#     trainNumber departureDate  operatorUICCode operatorShortCode trainType  \
# 0           276    2023-03-15               10                vr       PYO
# 1             4    2023-03-16               10                vr        IC
# 2            44    2023-03-16               10                vr         S
# 3            45    2023-03-16               10                vr        IC
# 4          8070    2023-03-16               10                vr        HL
# 5          8074    2023-03-16               10                vr        HL
# 6          8077    2023-03-16               10                vr        HL
# 7          8081    2023-03-16               10                vr        HL
# 8          8338    2023-03-16               10                vr        HL
# 9          8341    2023-03-16               10                vr        HL
# 10         8452    2023-03-16               10                vr        HL
# 11         8457    2023-03-16               10                vr        HL
# 12         8638    2023-03-16               10                vr        HL
# 13         8641    2023-03-16               10                vr        HL
# 14         8646    2023-03-16               10                vr        HL
# 15         8647    2023-03-16               10                vr        HL
# 16         8649    2023-03-16               10                vr        HL
# 17         8836    2023-03-16               10                vr        HL
# 18         8837    2023-03-16               10                vr        HL
# 19         8842    2023-03-16               10                vr        HL
# 20         8844    2023-03-16               10                vr        HL
# 21         9070    2023-03-16               10                vr        HL
# 22         9074    2023-03-16               10                vr        HL
# 23         9089    2023-03-16               10                vr        HL
# 24         9093    2023-03-16               10                vr        HL
# 25         9097    2023-03-16               10                vr        HL
# 26         9646    2023-03-16               10                vr        HL
# 27        60004    2023-03-16               10                vr       SAA
# 28        60065    2023-03-16               10                vr       SAA
# 29        61140    2023-03-16               10                vr       SAA
#
#     trainCategory commuterLineID  runningCurrently  cancelled       version  \
# 0   Long-distance                            False      False  285130841675
# 1   Long-distance                            False      False  285130823402
# 2   Long-distance                            False      False  285130890255
# 3   Long-distance                            False      False  285130841675
# 4        Commuter              A             False      False  285130828029
# 5        Commuter              A              True      False  285130908994
# 6        Commuter              A             False      False  285130899090
# 7        Commuter              A             False      False  285130892236
# 8        Commuter              E              True      False  285130912643
# 9        Commuter              E              True      False  285130901188
# 10       Commuter              U             False      False  285130818309
# 11       Commuter              U              True      False  285130916991
# 12       Commuter              P             False      False  285130834278
# 13       Commuter              P             False      False  285130916991
# 14       Commuter              P              True      False  285130909495
# 15       Commuter              P              True      False  285130915999
# 16       Commuter              P              True      False  285130906084
# 17       Commuter              I             False      False  285130901821
# 18       Commuter              I              True      False  285130915419
# 19       Commuter              I              True      False  285130914088
# 20       Commuter              I              True      False  285130911547
# 21       Commuter              K             False      False  285130873642
# 22       Commuter              K              True      False  285130914088
# 23       Commuter              K              True      False  285130904043
# 24       Commuter              K              True      False  285130911547
# 25       Commuter              K             False      False  285130897357
# 26       Commuter              R             False      False  285130869781
# 27       Shunting                            False      False  285130676309
# 28       Shunting                             True      False  285130871490
# 29       Shunting                            False       True  285129691628
#
#    timetableType   timetableAcceptanceDate  \
# 0        REGULAR  2022-11-03T06:29:25.000Z
# 1        REGULAR  2022-11-03T06:29:25.000Z
# 2        REGULAR  2022-11-03T06:29:25.000Z
# 3        REGULAR  2022-08-15T06:10:16.000Z
# 4        REGULAR  2022-12-15T06:04:43.000Z
# 5        REGULAR  2022-12-15T06:04:43.000Z
# 6        REGULAR  2022-12-15T06:04:43.000Z
# 7        REGULAR  2022-12-15T06:04:43.000Z
# 8        REGULAR  2022-12-15T06:04:43.000Z
# 9        REGULAR  2022-12-15T06:04:43.000Z
# 10       REGULAR  2022-12-15T06:04:43.000Z
# 11       REGULAR  2022-12-15T06:04:43.000Z
# 12       REGULAR  2022-12-15T06:04:43.000Z
# 13       REGULAR  2022-12-15T06:04:43.000Z
# 14       REGULAR  2022-12-15T06:04:43.000Z
# 15       REGULAR  2022-12-15T06:04:43.000Z
# 16       REGULAR  2022-12-15T06:04:43.000Z
# 17       REGULAR  2022-12-15T06:04:43.000Z
# 18       REGULAR  2022-12-15T06:04:43.000Z
# 19       REGULAR  2022-12-15T06:04:43.000Z
# 20       REGULAR  2022-12-15T06:04:43.000Z
# 21       REGULAR  2022-12-15T06:04:43.000Z
# 22       REGULAR  2022-12-15T06:04:43.000Z
# 23       REGULAR  2022-12-15T06:04:43.000Z
# 24       REGULAR  2022-12-15T06:04:43.000Z
# 25       REGULAR  2022-12-15T06:04:43.000Z
# 26       REGULAR  2022-11-03T06:29:25.000Z
# 27       REGULAR  2022-11-03T06:29:25.000Z
# 28       REGULAR  2022-11-03T06:29:25.000Z
# 29       REGULAR  2022-11-03T06:29:25.000Z
#
#                                         timeTableRows
# 0   [{'stationShortCode': 'KLI', 'stationUICCode':...
# 1   [{'stationShortCode': 'JNS', 'stationUICCode':...
# 2   [{'stationShortCode': 'VS', 'stationUICCode': ...
# 3   [{'stationShortCode': 'HKI', 'stationUICCode':...
# 4   [{'stationShortCode': 'LPV', 'stationUICCode':...
# 5   [{'stationShortCode': 'LPV', 'stationUICCode':...
# 6   [{'stationShortCode': 'HKI', 'stationUICCode':...
# 7   [{'stationShortCode': 'HKI', 'stationUICCode':...
# 8   [{'stationShortCode': 'KLH', 'stationUICCode':...
# 9   [{'stationShortCode': 'HKI', 'stationUICCode':...
# 10  [{'stationShortCode': 'KKN', 'stationUICCode':...
# 11  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 12  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 13  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 14  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 15  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 16  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 17  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 18  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 19  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 20  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 21  [{'stationShortCode': 'KE', 'stationUICCode': ...
# 22  [{'stationShortCode': 'KE', 'stationUICCode': ...
# 23  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 24  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 25  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 26  [{'stationShortCode': 'TPE', 'stationUICCode':...
# 27  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 28  [{'stationShortCode': 'ILR', 'stationUICCode':...
# 29  [{'stationShortCode': 'HKI', 'stationUICCode':...

# %% [markdown]
# #### Tehtävä 3. Poista kaikki muut sarakkeet paitsi `timeTableRows` ja `trainNumber`

# %%
#
# train_pd = train_pd[(train_pd["timeTableRows"]) & (train_pd["trainNumber"])]
# train_pd
train_df = train_df.loc[:,["trainNumber","timeTableRows"]]
train_df
# Out:
#     trainNumber                                      timeTableRows
# 0           276  [{'stationShortCode': 'KLI', 'stationUICCode':...
# 1             4  [{'stationShortCode': 'JNS', 'stationUICCode':...
# 2            44  [{'stationShortCode': 'VS', 'stationUICCode': ...
# 3            45  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 4          8070  [{'stationShortCode': 'LPV', 'stationUICCode':...
# 5          8074  [{'stationShortCode': 'LPV', 'stationUICCode':...
# 6          8077  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 7          8081  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 8          8338  [{'stationShortCode': 'KLH', 'stationUICCode':...
# 9          8341  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 10         8452  [{'stationShortCode': 'KKN', 'stationUICCode':...
# 11         8457  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 12         8638  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 13         8641  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 14         8646  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 15         8647  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 16         8649  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 17         8836  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 18         8837  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 19         8842  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 20         8844  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 21         9070  [{'stationShortCode': 'KE', 'stationUICCode': ...
# 22         9074  [{'stationShortCode': 'KE', 'stationUICCode': ...
# 23         9089  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 24         9093  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 25         9097  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 26         9646  [{'stationShortCode': 'TPE', 'stationUICCode':...
# 27        60004  [{'stationShortCode': 'HKI', 'stationUICCode':...
# 28        60065  [{'stationShortCode': 'ILR', 'stationUICCode':...
# 29        61140  [{'stationShortCode': 'HKI', 'stationUICCode':...

# %% [markdown]
# #### Tehtävä 4. Tämän jälkeen pura `timeTableRows` sarakkeen arvot jokaisesta junasta erikseen (sarakkeen arvo jokaiselle junalle sisältää useampia JSON-objekteja) ja lisää dataan mukaan junan tiedot yksilöivä `trainNumber`

# %%
#

t_list = []

for i in train_df["timeTableRows"]:
    for j in i:
        t_list.append(j)
# t_list
train_l = pd.DataFrame(t_list)    
train_l
# Out:
#      stationShortCode  stationUICCode countryCode       type  trainStopping  \
# 0                 KLI             358          FI  DEPARTURE           True
# 1                 SPJ             796          FI    ARRIVAL          False
# 2                 SPJ             796          FI  DEPARTURE          False
# 3                 PEL             356          FI    ARRIVAL           True
# 4                 PEL             356          FI  DEPARTURE           True
# ...               ...             ...         ...        ...            ...
# 1679              HKI               1          FI    ARRIVAL           True
# 1680              HKI               1          FI  DEPARTURE           True
# 1681              PSL              10          FI    ARRIVAL          False
# 1682              PSL              10          FI  DEPARTURE          False
# 1683              ILR            1030          FI    ARRIVAL           True
#
#      commercialStop commercialTrack  cancelled             scheduledTime  \
# 0              True               1      False  2023-03-15T17:42:00.000Z
# 1               NaN                      False  2023-03-15T17:59:00.000Z
# 2               NaN                      False  2023-03-15T17:59:00.000Z
# 3              True               1      False  2023-03-15T18:29:00.000Z
# 4              True               1      False  2023-03-15T18:32:00.000Z
# ...             ...             ...        ...                       ...
# 1679           True               9      False  2023-03-16T09:03:00.000Z
# 1680           True                       True  2023-03-16T08:14:00.000Z
# 1681            NaN                       True  2023-03-16T08:19:00.000Z
# 1682            NaN                       True  2023-03-16T08:19:00.000Z
# 1683           True                       True  2023-03-16T08:29:00.000Z
#
#                     actualTime  differenceInMinutes causes  trainNumber  \
# 0     2023-03-15T17:44:01.000Z                  2.0     []          276
# 1     2023-03-15T18:00:41.000Z                  2.0     []          276
# 2     2023-03-15T18:00:41.000Z                  2.0     []          276
# 3     2023-03-15T18:29:36.000Z                  1.0     []          276
# 4     2023-03-15T18:34:02.000Z                  2.0     []          276
# ...                        ...                  ...    ...          ...
# 1679                       NaN                 -7.0     []        60065
# 1680                       NaN                  NaN     []        61140
# 1681                       NaN                  NaN     []        61140
# 1682                       NaN                  NaN     []        61140
# 1683                       NaN                  NaN     []        61140
#
#                                              trainReady  \
# 0     {'source': 'KUPLA', 'accepted': True, 'timesta...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1679                                                NaN
# 1680                                                NaN
# 1681                                                NaN
# 1682                                                NaN
# 1683                                                NaN
#
#               liveEstimateTime estimateSource
# 0                          NaN            NaN
# 1                          NaN            NaN
# 2                          NaN            NaN
# 3                          NaN            NaN
# 4                          NaN            NaN
# ...                        ...            ...
# 1679  2023-03-16T08:55:50.000Z      COMBOCALC
# 1680                       NaN            NaN
# 1681                       NaN            NaN
# 1682                       NaN            NaN
# 1683                       NaN            NaN
#
# [1684 rows x 16 columns]

# %% [markdown]
# #### Tehtävä 5. Pudota sitten seuraavat sarakkeet datasta: `causes`, `estimateSource`, `liveEstimateTime`, `differenceInMinutes`, `commercialStop` ja `trainReady`

# %%
#
train_l.drop(["causes","estimateSource","liveEstimateTime","differenceInMinutes","commercialStop","trainReady"], inplace=True, axis=1)
train_l
# Out:
#      stationShortCode  stationUICCode countryCode       type  trainStopping  \
# 0                 KLI             358          FI  DEPARTURE           True
# 1                 SPJ             796          FI    ARRIVAL          False
# 2                 SPJ             796          FI  DEPARTURE          False
# 3                 PEL             356          FI    ARRIVAL           True
# 4                 PEL             356          FI  DEPARTURE           True
# ...               ...             ...         ...        ...            ...
# 1679              HKI               1          FI    ARRIVAL           True
# 1680              HKI               1          FI  DEPARTURE           True
# 1681              PSL              10          FI    ARRIVAL          False
# 1682              PSL              10          FI  DEPARTURE          False
# 1683              ILR            1030          FI    ARRIVAL           True
#
#      commercialTrack  cancelled             scheduledTime  \
# 0                  1      False  2023-03-15T17:42:00.000Z
# 1                         False  2023-03-15T17:59:00.000Z
# 2                         False  2023-03-15T17:59:00.000Z
# 3                  1      False  2023-03-15T18:29:00.000Z
# 4                  1      False  2023-03-15T18:32:00.000Z
# ...              ...        ...                       ...
# 1679               9      False  2023-03-16T09:03:00.000Z
# 1680                       True  2023-03-16T08:14:00.000Z
# 1681                       True  2023-03-16T08:19:00.000Z
# 1682                       True  2023-03-16T08:19:00.000Z
# 1683                       True  2023-03-16T08:29:00.000Z
#
#                     actualTime  trainNumber
# 0     2023-03-15T17:44:01.000Z          276
# 1     2023-03-15T18:00:41.000Z          276
# 2     2023-03-15T18:00:41.000Z          276
# 3     2023-03-15T18:29:36.000Z          276
# 4     2023-03-15T18:34:02.000Z          276
# ...                        ...          ...
# 1679                       NaN        60065
# 1680                       NaN        61140
# 1681                       NaN        61140
# 1682                       NaN        61140
# 1683                       NaN        61140
#
# [1684 rows x 10 columns]

# %% [markdown]
# #### Tehtävä 6. Täytä jokaisen rivin sarakkeen `actualTime` puuttuvat arvot `scheduledTime` -sarakkeen arvolla.

# %%
#
train_l['actualTime'].fillna(inplace=True,value=train_l['scheduledTime'])
train_l
# Out:
#      stationShortCode  stationUICCode countryCode       type  trainStopping  \
# 0                  JY             240          FI  DEPARTURE           True
# 1                 MUU             433          FI    ARRIVAL          False
# 2                 MUU             433          FI  DEPARTURE          False
# 3                 SAA             668          FI    ARRIVAL          False
# 4                 SAA             668          FI  DEPARTURE          False
# ...               ...             ...         ...        ...            ...
# 1357              ILR            1030          FI    ARRIVAL           True
# 1358              HKI               1          FI  DEPARTURE           True
# 1359              PSL              10          FI    ARRIVAL          False
# 1360              PSL              10          FI  DEPARTURE          False
# 1361              ILR            1030          FI    ARRIVAL           True
#
#      commercialTrack  cancelled             scheduledTime  \
# 0                  1      False  2023-03-14T12:20:00.000Z
# 1                         False  2023-03-14T12:29:00.000Z
# 2                         False  2023-03-14T12:29:00.000Z
# 3                         False  2023-03-14T12:38:00.000Z
# 4                         False  2023-03-14T12:38:00.000Z
# ...              ...        ...                       ...
# 1357             798      False  2023-03-14T16:14:00.000Z
# 1358               5      False  2023-03-14T16:19:00.000Z
# 1359                      False  2023-03-14T16:24:00.000Z
# 1360                      False  2023-03-14T16:24:00.000Z
# 1361             787      False  2023-03-14T16:34:00.000Z
#
#                     actualTime  trainNumber
# 0     2023-03-14T12:21:33.000Z           86
# 1     2023-03-14T12:30:24.000Z           86
# 2     2023-03-14T12:30:24.000Z           86
# 3     2023-03-14T12:39:08.000Z           86
# 4     2023-03-14T12:39:08.000Z           86
# ...                        ...          ...
# 1357  2023-03-14T16:15:34.000Z        64125
# 1358  2023-03-14T16:19:00.000Z        64127
# 1359  2023-03-14T16:24:00.000Z        64127
# 1360  2023-03-14T16:24:00.000Z        64127
# 1361  2023-03-14T16:34:00.000Z        64127
#
# [1362 rows x 10 columns]

# %% [markdown]
# ## Vaihe 2
#
# #### Tehtävä 7. Pura tämän kansion sisällä olevan `data.html` -tiedoston `table`-elementin solujen arvot käyttäen regex-syntaksia ja yhdistä ne vaiheessa 1 luotuun dataframeen. Huom: tehtävässä tulee käyttää vain regexiä (Esim. Pandasin read_html()-metodin käyttö on kielletty)!

# %%
import re
import urllib.request

# %%
url = 'file:///C:/Users/sanni/Aida/ttc8030-harjoitukset/harjoitustyo/data.html'
html = urllib.request.urlopen(url).read()
html = html.decode()

pattern = r'<th>(.*)</th>' #th:t
pattern2 = r'<td>\s+(.*?)\s+</td>' #kaikki td:t
ths = re.findall(pattern, html)
tds = re.findall(pattern2, html)
# ths
# tds

actualtime = tds[::10]
cancelled = tds[1::10]
commercialtrack =tds[2::10]
countrycode = tds[3::10]
scheduledtime = tds[4::10]
shortcode = tds[5::10]
uiccode = tds[6::10]
trainstopping = tds[7::10]
ttype = tds[8::10]
trainnumber = tds[9::10]

generated_dataframe = pd.DataFrame({ths[5]:shortcode,
                                    ths[6]:uiccode,
                                   ths[3]:countrycode,
                                    ths[8]:ttype,
                                   ths[7]:trainstopping,
                                   ths[2]:commercialtrack,
                                   ths[1]:cancelled,
                                   ths[4]:scheduledtime,
                                   ths[0]:actualtime,
                                   ths[9]:trainnumber})

# generated_dataframe

combined_df = pd.concat([train_l, generated_dataframe])
combined_df.reset_index(inplace=True,drop=True)
combined_df
# Out:
#      stationShortCode stationUICCode countryCode       type trainStopping  \
# 0                  JY            240          FI  DEPARTURE          True
# 1                 MUU            433          FI    ARRIVAL         False
# 2                 MUU            433          FI  DEPARTURE         False
# 3                 SAA            668          FI    ARRIVAL         False
# 4                 SAA            668          FI  DEPARTURE         False
# ...               ...            ...         ...        ...           ...
# 1360              PSL             10          FI  DEPARTURE         False
# 1361              ILR           1030          FI    ARRIVAL          True
# 1362              JVS           1272          FI  DEPARTURE         False
# 1363             R702          98998          FI    ARRIVAL         False
# 1364              ILA          98998          FI    ARRIVAL             9
#
#      commercialTrack cancelled             scheduledTime  \
# 0                  1     False  2023-03-14T12:20:00.000Z
# 1                        False  2023-03-14T12:29:00.000Z
# 2                        False  2023-03-14T12:29:00.000Z
# 3                        False  2023-03-14T12:38:00.000Z
# 4                        False  2023-03-14T12:38:00.000Z
# ...              ...       ...                       ...
# 1360                     False  2023-03-14T16:24:00.000Z
# 1361             787     False  2023-03-14T16:34:00.000Z
# 1362                     False  2019-08-06T04:48:00.000Z
# 1363                     False  2019-08-06T06:04:39.000Z
# 1364                     False  2019-08-06T07:03:12.000Z
#
#                     actualTime trainNumber
# 0     2023-03-14T12:21:33.000Z          86
# 1     2023-03-14T12:30:24.000Z          86
# 2     2023-03-14T12:30:24.000Z          86
# 3     2023-03-14T12:39:08.000Z          86
# 4     2023-03-14T12:39:08.000Z          86
# ...                        ...         ...
# 1360  2023-03-14T16:24:00.000Z       64127
# 1361  2023-03-14T16:34:00.000Z       64127
# 1362  2019-08-06T04:48:00.000Z         150
# 1363  2019-08-06T06:04:39.000Z         150
# 1364  2019-08-06T07:03:12.000Z        8337
#
# [1365 rows x 10 columns]

# %% [markdown]
# ## Vaihe 3
#
# #### Tehtävä 8. Tee SQLite tietokanta ja lisää sinne vaiheen 2 tuloksena saatu dataframe.

# %%
import sqlite3

# %%
# Tietokannan (train.db) luominen paikalliseen hakemistoon
conn = sqlite3.connect("train.db")
combined_df.to_sql(name='trains', con=conn, if_exists='fail', index=False)
conn.close()

# %%
# Tietokannan taulun kaikkien tietojen lukeminen
conn = sqlite3.connect('train.db')
sql_query = 'SELECT * FROM trains'
df = pd.read_sql_query(sql_query, conn)
conn.close()
df
# Out:
#      stationShortCode stationUICCode countryCode       type trainStopping  \
# 0                  JY            240          FI  DEPARTURE             1
# 1                 MUU            433          FI    ARRIVAL             0
# 2                 MUU            433          FI  DEPARTURE             0
# 3                 SAA            668          FI    ARRIVAL             0
# 4                 SAA            668          FI  DEPARTURE             0
# ...               ...            ...         ...        ...           ...
# 1360              PSL             10          FI  DEPARTURE             0
# 1361              ILR           1030          FI    ARRIVAL             1
# 1362              JVS           1272          FI  DEPARTURE         False
# 1363             R702          98998          FI    ARRIVAL         False
# 1364              ILA          98998          FI    ARRIVAL             9
#
#      commercialTrack cancelled             scheduledTime  \
# 0                  1         0  2023-03-14T12:20:00.000Z
# 1                            0  2023-03-14T12:29:00.000Z
# 2                            0  2023-03-14T12:29:00.000Z
# 3                            0  2023-03-14T12:38:00.000Z
# 4                            0  2023-03-14T12:38:00.000Z
# ...              ...       ...                       ...
# 1360                         0  2023-03-14T16:24:00.000Z
# 1361             787         0  2023-03-14T16:34:00.000Z
# 1362                     False  2019-08-06T04:48:00.000Z
# 1363                     False  2019-08-06T06:04:39.000Z
# 1364                     False  2019-08-06T07:03:12.000Z
#
#                     actualTime trainNumber
# 0     2023-03-14T12:21:33.000Z          86
# 1     2023-03-14T12:30:24.000Z          86
# 2     2023-03-14T12:30:24.000Z          86
# 3     2023-03-14T12:39:08.000Z          86
# 4     2023-03-14T12:39:08.000Z          86
# ...                        ...         ...
# 1360  2023-03-14T16:24:00.000Z       64127
# 1361  2023-03-14T16:34:00.000Z       64127
# 1362  2019-08-06T04:48:00.000Z         150
# 1363  2019-08-06T06:04:39.000Z         150
# 1364  2019-08-06T07:03:12.000Z        8337
#
# [1365 rows x 10 columns]
